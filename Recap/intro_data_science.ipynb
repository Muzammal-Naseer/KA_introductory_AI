# %% [markdown]
# # Introduction to Data Science

# %% [markdown]
# Guide to data preprocessing basics and handling.
#
# Created by **TA. Ahmed Almohammed**.

# %% [markdown]
# Conventions used in the notebook
#
# - 📖: This emoji indicates a reference to an external resource that could help
# you in understanding and digesting the topics mentioned.
#
# - 👋: This emoji indicates extra explanation about the topic discussed
#
# - 🔑: This emoji indicates the key take-away from the topic discussed

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 👋: `Pandas` is a library used for data analysis and manipulation of tabular data.
#
# 👋: `Numpy` is a library used for dealing with arrays and scientific compuatations in python.
#
# 👋: `Matplotlib` is a library used for data visualization and plotting of data.
#
# 👋: `Seaborn` is a library used for data visualization and plotting of data.

# %% [markdown]
# ## Numpy Basics

# %% [markdown]
# ### Creation of Arrays

# %%
# fist dimensioinal array
array1 = np.array([1,2,3])

# second dimensioinal array
array2 = np.array([[1,2,3]])

# third dimensioinal array
array3 = np.array([[[1,2,3]]])

# print the content of the array + its dimensions
print(array1.shape)
display(array1)
print(array2.shape)
display(array2)
print(array3.shape)
display(array3)
# Out:
# (3,)
# array([1, 2, 3])
# (1, 3)
# array([[1, 2, 3]])
# (1, 1, 3)
# array([[[1, 2, 3]]])

# %% [markdown]
# 🔑: A customized array can be instantiated instead of one from nothing. Such ones include `np.ones`, `np.zeros`, `np.random` and so on.

# %% [markdown]
# ### Indexing and Slicing Arrays

# %%
# random array with shape of (4, 4)
array = np.random.rand(4, 4)

arr = array[:2, :2]
ay = array[2:, 2:]


print(array.shape)
display(array)
print(arr.shape)
display(arr)
print(ay.shape)
display(ay)
# Out:
# (4, 4)
# array([[0.82230165, 0.60540649, 0.10756281, 0.61395643],
#        [0.56616788, 0.21183168, 0.99705844, 0.18450708],
#        [0.28014623, 0.73055874, 0.59818608, 0.04822168],
#        [0.63377874, 0.79833197, 0.71127268, 0.40510896]])
# (2, 2)
# array([[0.82230165, 0.60540649],
#        [0.56616788, 0.21183168]])
# (2, 2)
# array([[0.59818608, 0.04822168],
#        [0.71127268, 0.40510896]])

# %% [markdown]
# ### Understanding Dimensions

# %%
# create a random big array of integerrs
array = np.random.randint(10, size=(2,3,4,5))
array
# Out:
# array([[[[5, 6, 1, 1, 9],
#          [3, 4, 0, 5, 4],
#          [2, 2, 3, 7, 4],
#          [2, 7, 1, 8, 3]],
#
#         [[4, 0, 8, 8, 6],
#          [3, 9, 3, 4, 3],
#          [5, 7, 5, 0, 7],
#          [4, 4, 7, 4, 8]],
#
#         [[3, 0, 5, 4, 9],
#          [2, 5, 0, 6, 9],
#          [6, 6, 5, 8, 2],
#          [7, 2, 3, 4, 4]]],
#
#
#        [[[1, 6, 4, 8, 8],
#          [4, 2, 6, 4, 3],
#          [6, 3, 4, 9, 4],
#          [6, 9, 5, 6, 2]],
#
#         [[6, 3, 4, 2, 9],
#          [3, 5, 8, 4, 2],
#          [1, 7, 8, 5, 2],
#          [5, 3, 9, 5, 6]],
#
#         [[9, 8, 4, 1, 9],
#          [9, 8, 0, 9, 8],
#          [6, 7, 8, 9, 9],
#          [3, 2, 6, 5, 1]]]])

# %%
array.shape
# Out:
# (2, 3, 4, 5)

# %% [markdown]
# 👋: `array`'s shape is (2, 3, 4, 5), this means it gets displayed like so:
#
# - Inner most array = size 5
#
# - Next array = size 4
#
# - Next array = size 3
#
# - Outer most array = size 2

# %% [markdown]
# ## Pandas DataFrames

# %% [markdown]
# ### Creating a simple dataframe

# %%
# create the columns and rows
template = {
    'Name': ['Ahmed', 'Ali', 'Hassain', 'Mohseen'],
    'Age': [22,22,22,22],
    'City': ['AlAhsa', 'AlAhsa', 'AlAhsa', 'Riyadh'],
}

# creating the dataframe
dataframe = pd.DataFrame(template)

# view the first n rows
n = 3
dataframe.head(n)
# Out:
#       Name  Age    City
# 0    Ahmed   22  AlAhsa
# 1      Ali   22  AlAhsa
# 2  Hassain   22  AlAhsa

# %% [markdown]
# 👋: A dataframe consists of:
#
# - Columns and rows.
#
# - Each row is indexed starting from 0 for easy data retreival.
#
# - Sometimes the rows are referred to as observations or records.

# %% [markdown]
# ### Reading in a DataFrame

# %%
# download a sample tabular data file
# !wget https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales.csv

# read in the data
dataframe = pd.read_csv('car-sales.csv')

# view the last n rows
n = 4
dataframe.tail(n)
# Out:
# --2023-09-16 11:01:32--  https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369 [text/plain]
# Saving to: ‘car-sales.csv’
#
# car-sales.csv       100%[===================>]     369  --.-KB/s    in 0s
#
# 2023-09-16 11:01:32 (6.70 MB/s) - ‘car-sales.csv’ saved [369/369]
#      Make Colour  Odometer (KM)  Doors      Price
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# 🔑: Use the command `wget` to download any file in the internet!

# %% [markdown]
# ### Indexing and Slicing DataFrames

# %%
# to acquire certain rows
display(dataframe.iloc[3:])

# based on a condition
MASK = dataframe['Make'] == 'BMW'
display(dataframe[MASK])

# colmuns
display(dataframe.columns)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00
#   Make Colour  Odometer (KM)  Doors       Price
# 3  BMW  Black          11179      5  $22,000.00
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %% [markdown]
# 👋: The idea behind using a `MASK` is to allow for customized display or retreival
# of records that only satisty the condition in the `MASK`.

# %% [markdown]
# ## Hands On

# %% [markdown]
# We will now apply basic data analysis skills to a new dataset acquired from the
# internet

# %% [markdown]
# ### Download the data

# %%
# !wget https://raw.githubusercontent.com/selva86/datasets/master/ChickWeight.csv

data = pd.read_csv('ChickWeight.csv')
# Out:
# --2023-09-16 11:01:32--  https://raw.githubusercontent.com/selva86/datasets/master/ChickWeight.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6437 (6.3K) [text/plain]
# Saving to: ‘ChickWeight.csv’
#
# ChickWeight.csv     100%[===================>]   6.29K  --.-KB/s    in 0s
#
# 2023-09-16 11:01:32 (27.1 MB/s) - ‘ChickWeight.csv’ saved [6437/6437]

# %% [markdown]
# 👋: In addition to the varying functionalities provided by the `pandas` library,
# it contains several functions to read in data and have them ready for processing.
# Such common function includes the `pd.read_csv(FILE_NAME)` which reads in the CSV
# file named `FILE_NAME`.

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
# examine the data
data.head()
# Out:
#    weight  Time  Chick  Diet
# 0      42     0      1     1
# 1      51     4      1     1
# 2      59     8      1     1
# 3      64    12      1     1
# 4      76    16      1     1

# %%
# descriptive stats
display(data.describe())
# Out:
#            weight        Time       Chick        Diet
# count  578.000000  578.000000  578.000000  578.000000
# mean   121.818339   21.435986   25.750865    2.235294
# std     71.071960   13.516799   14.568795    1.162678
# min     35.000000    0.000000    1.000000    1.000000
# 25%     63.000000    8.000000   13.000000    1.000000
# 50%    103.000000   20.000000   26.000000    2.000000
# 75%    163.750000   32.000000   38.000000    3.000000
# max    373.000000   42.000000   50.000000    4.000000

# %% [markdown]
# 🔑: Use the `.describe()` function to display a statistical overview of the data.

# %%
# displaying unique values in the data for each column
display(data.nunique())
# Out:
# weight    212
# Time       12
# Chick      50
# Diet        4
# dtype: int64

# %% [markdown]
# 🔑: Use the `.nunique()` to display the number of unique values in each column.

# %% [markdown]
# Since we have 4 unique values for the diet, we can visualise the data
# by grouping all the chicks in their respected diet categories

# %%
len(data)
# Out:
# 578

# %%
display(data.pivot_table(columns=['Diet'], aggfunc='nunique'))
# Out:
# Diet      1   2   3   4
# Chick    20  10  10  10
# Time     12  12  12  12
# weight  122  91  96  90

# %% [markdown]
# 👋: We created a new table from the data based on the criteria we want. We wanted
# to see the chicks in each diet (unique ones, no duplicates)

# %% [markdown]
# To better visualise what we are aiming to do, we can create a plot of it:

# %%
# get the counts in each category (Diet)
table = data.pivot_table(columns=['Diet'], aggfunc='nunique')
counts = table.loc['Chick']
# create a bar chart for the values
plt.bar(counts.index, counts.values)
# plot the data
plt.xlabel('Diet')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# We can conclude the following from the observations made:
#
# - The chicken group on diet 1 seem to be averagely fatter
#
# - The diet 1 have 20 chickens while the other have only 10

# %% [markdown]
# Lets now compare the effect of the diets, ie. before (min. time) and after (max. time)

# %%
before_data = data[data['Time'] == data['Time'].min()]
after_data = data[data['Time'] == data['Time'].max()]

print(f'Before diet: There were {len(before_data)} chicks')
print(f'After diet: There were {len(after_data)} chicks')
# Out:
# Before diet: There were 50 chicks
# After diet: There were 45 chicks

# %% [markdown]
# We can clearly see that the number of chicks at the beginning is not equal
# to the number of chicks at the end. What happened to them?

# %%
# instead of using matplotlib, we can use seaborn library
plt.title('Before the Diet')
sns.countplot(data=before_data, x='Diet');

# %%
plt.title('After the Diet')
sns.countplot(data=after_data, x='Diet');

# %% [markdown]
# We can see that 4 chicks are missing from Diet 1, in addition to 1 from Diet 4.

# %%
# lets group the data by the unique chicks and find the ones that didnt make it
data_chick = data.groupby('Chick')
data_chick.describe()
# Out:
#       weight                                                             Time  \
#        count        mean         std   min    25%    50%     75%    max count
# Chick
# 1       12.0  111.666667   57.731878  42.0  62.75   99.5  154.50  205.0  12.0
# 2       12.0  119.916667   62.304908  40.0  68.50  112.5  168.25  215.0  12.0
# 3       12.0  115.833333   60.713685  39.0  64.00  107.0  169.00  202.0  12.0
# 4       12.0   99.333333   43.650124  42.0  64.25   94.5  140.50  160.0  12.0
# 5       12.0  126.666667   72.368166  41.0  57.00  123.5  197.50  223.0  12.0
# 6       12.0  113.750000   46.917965  41.0  70.25  132.5  155.50  160.0  12.0
# 7       12.0  150.000000   95.547228  41.0  67.50  129.0  226.00  305.0  12.0
# 8       11.0   92.000000   32.619013  42.0  66.00   93.0  120.50  134.0  11.0
# 9       12.0   81.166667   20.608177  42.0  65.75   91.0   96.50  100.0  12.0
# 10      12.0   83.083333   28.842703  41.0  60.25   85.0  103.75  124.0  12.0
# ...

# %% [markdown]
# We can visually from the table see the chicks that didnt make it, however, we
# can write a line of code that returns to us the abnormal chicks:

# %%
# every chick complete 12 days with the diet, so the ones that didnt make it
# are what we are looking for.

MASK = np.array(data_chick.describe()['Diet']['count'] == 12)
chicks = data_chick.describe().index
missing_chicks = chicks[~MASK]
missing_chicks.values
# Out:
# array([ 8, 15, 16, 18, 44])

# %% [markdown]
# Yay! We found the missing chicks. We can remove them and ensure consistent findings.

# %% [markdown]
# You can continue from here and explore additional insights from this dataset

# %% [markdown]
# The end.

# %% [markdown]
# ## Resources

# %% [markdown]
# - 📖: [Feature Engineering in Python 1](https://towardsdatascience.com/feature-engineering-in-python-part-i-the-most-powerful-way-of-dealing-with-data-8e2447e7c69e)
#
# - 📖: [Feature Engineering in Python 2](https://medium.com/@serkanemreelci/feature-engineering-and-linear-regression-470dd9879e37#:~:text=It%20is%20possible%20to%20automatically,for%20a%20machine%20learning%20project.)
#
# - 📖: [Preprocessing Data using Pandas](https://levelup.gitconnected.com/the-importance-of-data-preprocessing-in-python-pandas-bfbc112ae28c)
#
# - 📖: [Basic Guide to Numpy Arrays](https://numpy.org/doc/stable/user/absolute_beginners.html)
#
# - 📖: [Basic Guide to Matplotlib Plots](https://www.geeksforgeeks.org/graph-plotting-in-python-set-1/)
